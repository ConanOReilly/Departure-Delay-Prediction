# %% [markdown]
# # **Airport Filter**
# The following code filters the dataset for entries from specific airport for a more narrower analysis.

# %%
import pandas as pd

dataset_path = 'balanced_dataset111.csv'
df = pd.read_csv(dataset_path)

print("Displaying the first 5 rows of the dataset:")
df.head()
# Out:
# Displaying the first 5 rows of the dataset:
#    MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  SEGMENT_NUMBER  \
# 0      3            7          1    1100-1159               1               3
# 1      6            7          1    1700-1759               3               4
# 2     10            5          1    2000-2059               3               7
# 3     12            2          0    2200-2259               2               5
# 4      1            2          1    2000-2059               5               4
#
#    CONCURRENT_FLIGHTS  NUMBER_OF_SEATS            CARRIER_NAME  \
# 0                   5               50             Comair Inc.
# 1                   5              180  Frontier Airlines Inc.
# 2                  66               66   SkyWest Airlines Inc.
# 3                  63              199    Delta Air Lines Inc.
# 4                  14              175  Southwest Airlines Co.
#
# ...

# %%
# extracting and displaying unique airport names
print("List of all unique airport names:")
airport_names = df['DEPARTING_AIRPORT'].unique()
print(airport_names)

print("\nTotal number of unique airports:", len(airport_names))
# Out:
# List of all unique airport names:
# ['McGhee Tyson' 'General Mitchell Field' "Chicago O'Hare International"
#  'Atlanta Municipal' 'Chicago Midway International'
#  'Houston Intercontinental' 'Sacramento International'
#  'John F. Kennedy International' 'Jacksonville International'
#  'Salt Lake City International' 'William P Hobby' 'Logan International'
#  'El Paso International' 'Raleigh-Durham International'
#  'Seattle International' 'Miami International' 'Kansas City International'
#  'Phoenix Sky Harbor International' 'Minneapolis-St Paul International'
#  'Newark Liberty International' 'Port Columbus International'
#  'San Diego International Lindbergh Fl' 'LaGuardia'
#  'Philadelphia International' 'San Jose International'
#  'Honolulu International' 'Syracuse Hancock International'
#  'Lambert-St. Louis International' 'Washington Dulles International'
#  'San Antonio International' 'Dallas Fort Worth Regional'
#  'Southwest Florida International' 'Los Angeles International'
# ...

# %%
# filtering the dataset to only keep rows where DEPARTING_AIRPORT is 'John F. Kennedy International'
filtered_df = df[df['DEPARTING_AIRPORT'] == 'John F. Kennedy International']

# displaying the filtered dataset
print("Filtered dataset with only 'John F. Kennedy International':")
print(filtered_df)

filtered_df.to_csv('filtered_dataset.csv', index=False)
# Out:
# Filtered dataset with only 'John F. Kennedy International':
#          MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  \
# 8            5            4          0    1300-1359               3
# 139         12            1          1    1200-1259              10
# 168          5            4          0    0700-0759               1
# 177         10            4          0    0700-0759               5
# 216         12            6          0    1500-1559               3
# ...        ...          ...        ...          ...             ...
# 2454479     11            3          0    1900-1959               1
# 2454490      8            4          1    1400-1459               4
# 2454502      7            2          1    1800-1859               4
# 2454684      9            4          1    1900-1959              10
# 2454715      8            4          1    1600-1659               3
#
#          SEGMENT_NUMBER  CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  \
# ...
