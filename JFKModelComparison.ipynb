# %% [markdown]
# # **Machine Learning Model Comparison**
# To get better accuracy from our predictive models, focus was put on one airport, JKF. Again, underampling was used to balance the data.
#
# The same models were used:
#
# *   Logistic Regression.
# *   Decision Tree.
# *   Random Forest.
# *   XGBoost.
# *   Lasso.
# *   SVM.
#
# A stacking ensembled model and a DNN were executed and evaluated.

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from xgboost import plot_importance
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, f1_score
from sklearn.metrics import roc_curve, roc_auc_score

# %%
# Read dataset
df = pd.read_csv('/content/drive/MyDrive/Predictive Analysis/Predictive Analysis CA/Data/filtered_JFK_dataset.csv')

# %%
# Display head
df.head()
# Out:
#    MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  SEGMENT_NUMBER  \
# 0      5            4          0    1300-1359               3               3
# 1     12            1          1    1200-1259              10               2
# 2      5            4          0    0700-0759               1               2
# 3     10            4          0    0700-0759               5               2
# 4     12            6          0    1500-1559               3               4
#
#    CONCURRENT_FLIGHTS  NUMBER_OF_SEATS          CARRIER_NAME  \
# 0                  20              110  Delta Air Lines Inc.
# 1                  10              159       JetBlue Airways
# 2                  26              100       JetBlue Airways
# 3                  22              150       JetBlue Airways
# 4                  25              100       JetBlue Airways
#
#    AIRPORT_FLIGHTS_MONTH  ...  PLANE_AGE              DEPARTING_AIRPORT  \
# 0                  10815  ...         17  John F. Kennedy International
# 1                  10395  ...          2  John F. Kennedy International
# 2                  10815  ...         10  John F. Kennedy International
# 3                  10451  ...         15  John F. Kennedy International
# 4                  10395  ...         13  John F. Kennedy International
#
#    LATITUDE  LONGITUDE              PREVIOUS_AIRPORT  PRCP  SNOW SNWD  TMAX  \
# 0    40.639    -73.777             Douglas Municipal  0.00   0.0  0.0  71.0
# 1    40.639    -73.777     Los Angeles International  0.49   0.0  0.0  43.0
# 2    40.639    -73.777       Rochester Monroe County  0.00   0.0  0.0  71.0
# 3    40.639    -73.777  Salt Lake City International  0.39   0.0  0.0  67.0
# 4    40.639    -73.777       Rochester Monroe County  0.00   0.0  0.0  35.0
#
#     AWND
# 0   7.83
# 1  17.90
# 2   7.83
# 3  16.11
# 4   4.70
#
# [5 rows x 26 columns]

# %%
# Count of rows and columns
df.shape
# Out:
# (47435, 26)

# %%
# Display data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47435 entries, 0 to 47434
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   MONTH                          47435 non-null  int64
#  1   DAY_OF_WEEK                    47435 non-null  int64
#  2   DEP_DEL15                      47435 non-null  int64
#  3   DEP_TIME_BLK                   47435 non-null  object
#  4   DISTANCE_GROUP                 47435 non-null  int64
#  5   SEGMENT_NUMBER                 47435 non-null  int64
#  6   CONCURRENT_FLIGHTS             47435 non-null  int64
#  7   NUMBER_OF_SEATS                47435 non-null  int64
#  8   CARRIER_NAME                   47435 non-null  object
#  9   AIRPORT_FLIGHTS_MONTH          47435 non-null  int64
#  10  AIRLINE_FLIGHTS_MONTH          47435 non-null  int64
#  11  AIRLINE_AIRPORT_FLIGHTS_MONTH  47435 non-null  int64
#  12  AVG_MONTHLY_PASS_AIRPORT       47435 non-null  int64
#  13  AVG_MONTHLY_PASS_AIRLINE       47435 non-null  int64
#  14  FLT_ATTENDANTS_PER_PASS        47435 non-null  float64
#  15  GROUND_SERV_PER_PASS           47435 non-null  float64
#  16  PLANE_AGE                      47435 non-null  int64
#  17  DEPARTING_AIRPORT              47435 non-null  object
#  18  LATITUDE                       47435 non-null  float64
#  19  LONGITUDE                      47435 non-null  float64
#  20  PREVIOUS_AIRPORT               47435 non-null  object
#  21  PRCP                           47435 non-null  float64
#  22  SNOW                           47435 non-null  float64
#  23  SNWD                           47435 non-null  float64
#  24  TMAX                           47435 non-null  float64
#  25  AWND                           47435 non-null  float64
# dtypes: float64(9), int64(13), object(4)
# memory usage: 9.4+ MB

# %%
# Count null values
df.isnull().sum()
# Out:
# MONTH                            0
# DAY_OF_WEEK                      0
# DEP_DEL15                        0
# DEP_TIME_BLK                     0
# DISTANCE_GROUP                   0
# SEGMENT_NUMBER                   0
# CONCURRENT_FLIGHTS               0
# NUMBER_OF_SEATS                  0
# CARRIER_NAME                     0
# AIRPORT_FLIGHTS_MONTH            0
# AIRLINE_FLIGHTS_MONTH            0
# AIRLINE_AIRPORT_FLIGHTS_MONTH    0
# AVG_MONTHLY_PASS_AIRPORT         0
# AVG_MONTHLY_PASS_AIRLINE         0
# FLT_ATTENDANTS_PER_PASS          0
# GROUND_SERV_PER_PASS             0
# PLANE_AGE                        0
# DEPARTING_AIRPORT                0
# LATITUDE                         0
# LONGITUDE                        0
# PREVIOUS_AIRPORT                 0
# PRCP                             0
# SNOW                             0
# SNWD                             0
# TMAX                             0
# AWND                             0
# dtype: int64

# %% [markdown]
# # **Logical Regression**

# %%
# Extract numeric time from 'DEP_TIME_BLK'
df['DEP_TIME_START'] = df['DEP_TIME_BLK'].str.split('-').str[0].astype(int)

# Convert categorical variables into numerical values
label_encoder = LabelEncoder()

# Example: Encoding 'CARRIER_NAME' and 'DEPARTING_AIRPORT'
df['CARRIER_NAME'] = label_encoder.fit_transform(df['CARRIER_NAME'])
df['DEPARTING_AIRPORT'] = label_encoder.fit_transform(df['DEPARTING_AIRPORT'])

# Handle missing values if any
df = df.dropna()

# Select features and target variable
X = df[['MONTH', 'DAY_OF_WEEK', 'DEP_TIME_START', 'DISTANCE_GROUP',
        'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS',
        'AIRPORT_FLIGHTS_MONTH', 'PLANE_AGE', 'LATITUDE', 'LONGITUDE',
        'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND']]  # Add or remove features as necessary

# Target variable
y = df['DEP_DEL15']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardise the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the logistic regression model
model = LogisticRegression(max_iter=1000)
model.fit(X_train_scaled, y_train)

# Predictions and Evaluation
y_pred = model.predict(X_test_scaled)

# Evaluate model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.6277141451760242
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.62      0.62      7147
#            1       0.62      0.64      0.63      7084
#
#     accuracy                           0.63     14231
#    macro avg       0.63      0.63      0.63     14231
# weighted avg       0.63      0.63      0.63     14231
#
# Confusion Matrix:
#  [[4411 2736]
#  [2562 4522]]

# %% [markdown]
# **Threshold Tuning for Logistic Regression**

# %%
# Get probabilities for the positive class
y_pred_prob = model.predict_proba(X_test_scaled)[:, 1]

# Threshold tuning for F1 score
highest_f1 = 0
optimal_threshold = 0

thresholds = np.arange(0, 1, 0.01)
f1_scores = []

for t in thresholds:
    y_pred_custom = (y_pred_prob >= t).astype(int)
    score = f1_score(y_test, y_pred_custom)
    f1_scores.append(score)
    if score > highest_f1:
        highest_f1 = score
        optimal_threshold = t

# Print results
print("Highest F1 Score on Test Set:", highest_f1)
print("Optimal Threshold:", optimal_threshold)

# Plot F1 score vs. thresholds
plt.figure(figsize=(8, 5))
plt.plot([0.5, 0.5], [min(f1_scores), max(f1_scores)], linestyle='--', label="Default Threshold (0.5)")
plt.plot([optimal_threshold, optimal_threshold], [min(f1_scores), max(f1_scores)], linestyle='-', label=f"Optimal Threshold ({optimal_threshold:.2f})")
plt.plot(thresholds, f1_scores, marker='.', label="F1 Score Curve")
plt.title('F1 Score vs. Thresholds')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# Evaluate model with the optimal threshold
y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

# Final evaluation metrics
print("Classification Report with Optimal Threshold:\n", classification_report(y_test, y_pred_optimal))
print("Confusion Matrix with Optimal Threshold:\n", confusion_matrix(y_test, y_pred_optimal))
# Out:
# Highest F1 Score on Test Set: 0.67783964967292
# Optimal Threshold: 0.36
# Classification Report with Optimal Threshold:
#                precision    recall  f1-score   support
#
#            0       0.71      0.28      0.40      7147
#            1       0.55      0.88      0.68      7084
#
#     accuracy                           0.58     14231
#    macro avg       0.63      0.58      0.54     14231
# weighted avg       0.63      0.58      0.54     14231
#
# Confusion Matrix with Optimal Threshold:
#  [[2003 5144]
#  [ 815 6269]]

# %% [markdown]
# **F1 Score Tuning for Logistic Regression**

# %%
# Get probabilities for the positive class
y_pred_prob = model.predict_proba(X_test_scaled)[:, 1]

# F1 score tuning
highest_f1 = 0
optimal_threshold = 0

thresholds = np.arange(0, 1, 0.01)
f1_scores = []

for t in thresholds:
    y_pred_custom = (y_pred_prob >= t).astype(int)
    score = f1_score(y_test, y_pred_custom)
    f1_scores.append(score)
    if score > highest_f1:
        highest_f1 = score
        optimal_threshold = t

# Print results
print("Highest F1 Score on Test Set:", highest_f1)
print("Optimal Threshold:", optimal_threshold)

# Plot F1 score vs. thresholds
plt.figure(figsize=(8, 5))
plt.plot(thresholds, f1_scores, marker='.', label="F1 Score Curve")
plt.axvline(x=0.5, color='blue', linestyle='--', label="Default Threshold (0.5)")
plt.axvline(x=optimal_threshold, color='orange', linestyle='-', label=f"Optimal Threshold ({optimal_threshold:.2f})")
plt.title('F1 Score vs. Thresholds (Logistic Regression)')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# Evaluate model with the optimal threshold
y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

# Final evaluation metrics
print("Classification Report with Optimal Threshold:\n", classification_report(y_test, y_pred_optimal))
print("Confusion Matrix with Optimal Threshold:\n", confusion_matrix(y_test, y_pred_optimal))
# Out:
# Highest F1 Score on Test Set: 0.67783964967292
# Optimal Threshold: 0.36
# Classification Report with Optimal Threshold:
#                precision    recall  f1-score   support
#
#            0       0.71      0.28      0.40      7147
#            1       0.55      0.88      0.68      7084
#
#     accuracy                           0.58     14231
#    macro avg       0.63      0.58      0.54     14231
# weighted avg       0.63      0.58      0.54     14231
#
# Confusion Matrix with Optimal Threshold:
#  [[2003 5144]
#  [ 815 6269]]

# %% [markdown]
# # **DecisionTreeClassifier**

# %%
# Extract numeric time from 'DEP_TIME_BLK'
df['DEP_TIME_START'] = df['DEP_TIME_BLK'].str.split('-').str[0].astype(int)

# Convert categorical variables into numerical values
label_encoder = LabelEncoder()

# Example: Encoding 'CARRIER_NAME' and 'DEPARTING_AIRPORT'
df['CARRIER_NAME'] = label_encoder.fit_transform(df['CARRIER_NAME'])
df['DEPARTING_AIRPORT'] = label_encoder.fit_transform(df['DEPARTING_AIRPORT'])

# Handle missing values if any
df = df.dropna()

# Step 2: Select features and target variable
X = df[['MONTH', 'DAY_OF_WEEK', 'DEP_TIME_START', 'DISTANCE_GROUP',
        'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS',
        'AIRPORT_FLIGHTS_MONTH', 'PLANE_AGE', 'LATITUDE', 'LONGITUDE',
        'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND']]

# Target variable
y = df['DEP_DEL15']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardise the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the Decision Tree Classifier model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train_scaled, y_train)

# Predictions and Evaluation
y_pred = model.predict(X_test_scaled)

# Evaluate model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.6015037593984962
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60      7147
#            1       0.60      0.60      0.60      7084
#
#     accuracy                           0.60     14231
#    macro avg       0.60      0.60      0.60     14231
# weighted avg       0.60      0.60      0.60     14231
#
# Confusion Matrix:
#  [[4284 2863]
#  [2808 4276]]

# %% [markdown]
# **Threshold tuning For DecisionTreeClassifier**

# %%
# Get probabilities for the positive class
y_pred_prob = model.predict_proba(X_test_scaled)[:, 1]

# Threshold tuning for F1 score
highest_f1 = 0
optimal_threshold = 0

thresholds = np.arange(0, 1, 0.01)
f1_scores = []

for t in thresholds:
    y_pred_custom = (y_pred_prob >= t).astype(int)
    score = f1_score(y_test, y_pred_custom)
    f1_scores.append(score)
    if score > highest_f1:
        highest_f1 = score
        optimal_threshold = t

# Print results
print("Highest F1 Score on Test Set:", highest_f1)
print("Optimal Threshold:", optimal_threshold)

# Plot F1 score vs. thresholds
plt.figure(figsize=(8, 5))
plt.plot(thresholds, f1_scores, marker='.', label="F1 Score Curve")
plt.axvline(x=0.5, color='blue', linestyle='--', label="Default Threshold (0.5)")
plt.axvline(x=optimal_threshold, color='orange', linestyle='-', label=f"Optimal Threshold ({optimal_threshold:.2f})")
plt.title('F1 Score vs. Thresholds (Decision Tree Classifier)')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# Evaluate model with the optimal threshold
y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

# Final evaluation metrics
print("Classification Report with Optimal Threshold:\n", classification_report(y_test, y_pred_optimal))
print("Confusion Matrix with Optimal Threshold:\n", confusion_matrix(y_test, y_pred_optimal))
# Out:
# Highest F1 Score on Test Set: 0.664696223316913
# Optimal Threshold: 0.0
# Classification Report with Optimal Threshold:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      7147
#            1       0.50      1.00      0.66      7084
#
#     accuracy                           0.50     14231
#    macro avg       0.25      0.50      0.33     14231
# weighted avg       0.25      0.50      0.33     14231
#
# Confusion Matrix with Optimal Threshold:
#  [[   0 7147]
#  [   0 7084]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **F1 Score Tuning For DecisionTreeClassifier**

# %%
# Get probabilities for the positive class
y_pred_prob = model.predict_proba(X_test_scaled)[:, 1]

# F1 Score Tuning
highest_f1 = 0
optimal_threshold = 0

thresholds = np.arange(0, 1, 0.01)
f1_scores = []

for t in thresholds:
    y_pred_custom = (y_pred_prob >= t).astype(int)
    score = f1_score(y_test, y_pred_custom)
    f1_scores.append(score)
    if score > highest_f1:
        highest_f1 = score
        optimal_threshold = t

# Print results
print("Highest F1 Score on Test Set:", highest_f1)
print("Optimal Threshold for F1 Score:", optimal_threshold)

# Plot F1 score vs. thresholds
plt.figure(figsize=(8, 5))
plt.plot(thresholds, f1_scores, marker='.', label="F1 Score Curve")
plt.axvline(x=0.5, color='blue', linestyle='--', label="Default Threshold (0.5)")
plt.axvline(x=optimal_threshold, color='orange', linestyle='-', label=f"Optimal Threshold ({optimal_threshold:.2f})")
plt.title('F1 Score vs. Thresholds (Decision Tree Classifier)')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# Evaluate model with the optimal threshold
y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

# Final evaluation metrics
print("Classification Report with Optimal Threshold:\n", classification_report(y_test, y_pred_optimal))
print("Confusion Matrix with Optimal Threshold:\n", confusion_matrix(y_test, y_pred_optimal))
# Out:
# Highest F1 Score on Test Set: 0.664696223316913
# Optimal Threshold for F1 Score: 0.0
# Classification Report with Optimal Threshold:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      7147
#            1       0.50      1.00      0.66      7084
#
#     accuracy                           0.50     14231
#    macro avg       0.25      0.50      0.33     14231
# weighted avg       0.25      0.50      0.33     14231
#
# Confusion Matrix with Optimal Threshold:
#  [[   0 7147]
#  [   0 7084]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # **Random Forest**

# %%
# Extract numeric time from 'DEP_TIME_BLK'
df['DEP_TIME_START'] = df['DEP_TIME_BLK'].str.split('-').str[0].astype(int)

# Convert categorical variables into numerical values
label_encoder = LabelEncoder()

# Example: Encoding 'CARRIER_NAME' and 'DEPARTING_AIRPORT'
df['CARRIER_NAME'] = label_encoder.fit_transform(df['CARRIER_NAME'])
df['DEPARTING_AIRPORT'] = label_encoder.fit_transform(df['DEPARTING_AIRPORT'])

# Handle missing values if any
df = df.dropna()

# Select features and target variable
X = df[['MONTH', 'DAY_OF_WEEK', 'DEP_TIME_START', 'DISTANCE_GROUP',
        'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS',
        'AIRPORT_FLIGHTS_MONTH', 'PLANE_AGE', 'LATITUDE', 'LONGITUDE',
        'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND']]

# Target variable
y = df['DEP_DEL15']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardise the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the Random Forest Classifier model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_scaled, y_train)

# Predictions and Evaluation
y_pred = model.predict(X_test_scaled)

# Evaluate model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.6690323940692854
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.70      0.68      7147
#            1       0.68      0.64      0.66      7084
#
#     accuracy                           0.67     14231
#    macro avg       0.67      0.67      0.67     14231
# weighted avg       0.67      0.67      0.67     14231
#
# Confusion Matrix:
#  [[5011 2136]
#  [2574 4510]]

# %% [markdown]
# **Threshold Tuning For Random Forest**

# %%
# Get probabilities for the positive class
y_pred_prob = model.predict_proba(X_test_scaled)[:, 1]

# F1 Score Tuning
highest_f1 = 0
optimal_threshold = 0

thresholds = np.arange(0, 1, 0.01)
f1_scores = []

for t in thresholds:
    y_pred_custom = (y_pred_prob >= t).astype(int)
    score = f1_score(y_test, y_pred_custom)
    f1_scores.append(score)
    if score > highest_f1:
        highest_f1 = score
        optimal_threshold = t

# Print results
print("Highest F1 Score on Test Set:", highest_f1)
print("Optimal Threshold for F1 Score:", optimal_threshold)

# Plot F1 score vs. thresholds
plt.figure(figsize=(8, 5))
plt.plot(thresholds, f1_scores, marker='.', label="F1 Score Curve")
plt.axvline(x=0.5, color='blue', linestyle='--', label="Default Threshold (0.5)")
plt.axvline(x=optimal_threshold, color='orange', linestyle='-', label=f"Optimal Threshold ({optimal_threshold:.2f})")
plt.title('F1 Score vs. Thresholds (Random Forest Classifier)')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# Evaluate model with the optimal threshold
y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

# Final evaluation metrics
print("Classification Report with Optimal Threshold:\n", classification_report(y_test, y_pred_optimal))
print("Confusion Matrix with Optimal Threshold:\n", confusion_matrix(y_test, y_pred_optimal))
# Out:
# Highest F1 Score on Test Set: 0.6981573392663586
# Optimal Threshold for F1 Score: 0.33
# Classification Report with Optimal Threshold:
#                precision    recall  f1-score   support
#
#            0       0.75      0.39      0.52      7147
#            1       0.59      0.86      0.70      7084
#
#     accuracy                           0.63     14231
#    macro avg       0.67      0.63      0.61     14231
# weighted avg       0.67      0.63      0.61     14231
#
# Confusion Matrix with Optimal Threshold:
#  [[2821 4326]
#  [ 965 6119]]

# %% [markdown]
# **F1 Score Tuning For Random Forest**

# %%
# Get probabilities for the positive class
y_pred_prob = model.predict_proba(X_test_scaled)[:, 1]

# Initialise variables for F1 score tuning
highest_f1 = 0
optimal_threshold = 0

# Define a range of thresholds to test
thresholds = np.arange(0, 1, 0.01)
f1_scores = []

for t in thresholds:
    y_pred_custom = (y_pred_prob >= t).astype(int)
    score = f1_score(y_test, y_pred_custom)
    f1_scores.append(score)
    if score > highest_f1:
        highest_f1 = score
        optimal_threshold = t

# Print the highest F1 score and the optimal threshold
print("Highest F1 Score on Test Set:", highest_f1)
print("Optimal Threshold for F1 Score:", optimal_threshold)

# Plot F1 score vs. thresholds
plt.figure(figsize=(8, 5))
plt.plot(thresholds, f1_scores, marker='.', label="F1 Score Curve")
plt.axvline(x=0.5, color='blue', linestyle='--', label="Default Threshold (0.5)")
plt.axvline(x=optimal_threshold, color='orange', linestyle='-', label=f"Optimal Threshold ({optimal_threshold:.2f})")
plt.title('F1 Score vs. Thresholds (Random Forest Classifier)')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# Evaluate the model with the optimal threshold
y_pred_optimal = (y_pred_prob >= optimal_threshold).astype(int)

# Final evaluation metrics
print("Classification Report with Optimal Threshold:\n", classification_report(y_test, y_pred_optimal))
print("Confusion Matrix with Optimal Threshold:\n", confusion_matrix(y_test, y_pred_optimal))
# Out:
# Highest F1 Score on Test Set: 0.6981573392663586
# Optimal Threshold for F1 Score: 0.33
# Classification Report with Optimal Threshold:
#                precision    recall  f1-score   support
#
#            0       0.75      0.39      0.52      7147
#            1       0.59      0.86      0.70      7084
#
#     accuracy                           0.63     14231
#    macro avg       0.67      0.63      0.61     14231
# weighted avg       0.67      0.63      0.61     14231
#
# Confusion Matrix with Optimal Threshold:
#  [[2821 4326]
#  [ 965 6119]]

# %% [markdown]
# # **XGboost**

# %%
# Extract numeric time from 'DEP_TIME_BLK'
df['DEP_TIME_START'] = df['DEP_TIME_BLK'].str.split('-').str[0].astype(int)

# Convert categorical variables into numerical values
label_encoder = LabelEncoder()

# Encoding 'CARRIER_NAME' and 'DEPARTING_AIRPORT'
df['CARRIER_NAME'] = label_encoder.fit_transform(df['CARRIER_NAME'])
df['DEPARTING_AIRPORT'] = label_encoder.fit_transform(df['DEPARTING_AIRPORT'])

# Handle missing values
df = df.dropna()

# Select features and target variable
X = df[['MONTH', 'DAY_OF_WEEK', 'DEP_TIME_START', 'DISTANCE_GROUP',
        'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS',
        'AIRPORT_FLIGHTS_MONTH', 'PLANE_AGE', 'LATITUDE', 'LONGITUDE',
        'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND']]

# Target variable
y = df['DEP_DEL15']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardise the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the XGBoost model
model = XGBClassifier(n_estimators=100, random_state=42, use_label_encoder=False, eval_metric='logloss')
model.fit(X_train_scaled, y_train)

# Predictions and Evaluation
y_pred = model.predict(X_test_scaled)

# Evaluate model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.6799241093387675
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69      7147
#            1       0.69      0.65      0.67      7084
#
#     accuracy                           0.68     14231
#    macro avg       0.68      0.68      0.68     14231
# weighted avg       0.68      0.68      0.68     14231
#
# Confusion Matrix:
#  [[5097 2050]
#  [2505 4579]]
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:53:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# **Threshold Tuning For XGboost**

# %%
# Predict probabilities
y_pred_prob = model.predict_proba(X_test_scaled)[:, 1]

# Calculate accuracy for different thresholds
highest_accuracy = 0
threshold_highest_accuracy = 0

thresholds = np.arange(0, 1, 0.01)
scores = []

for t in thresholds:
    y_pred_custom = (y_pred_prob >= t).astype(int)
    score = accuracy_score(y_test, y_pred_custom)
    scores.append(score)
    if score > highest_accuracy:
        highest_accuracy = score
        threshold_highest_accuracy = t

print("Highest Accuracy on Test Set:", highest_accuracy)
print("Threshold for Highest Accuracy:", threshold_highest_accuracy)

# Plot accuracy vs. thresholds
plt.plot([0.5, 0.5], [np.min(scores), np.max(scores)], linestyle='--', label="Default Threshold (0.5)")
plt.plot([threshold_highest_accuracy, threshold_highest_accuracy], [np.min(scores), np.max(scores)], linestyle='-', label=f"Optimal Threshold ({threshold_highest_accuracy:.2f})")
plt.plot(thresholds, scores, marker='.', label="Accuracy Curve")
plt.title('Accuracy vs. Thresholds')
plt.xlabel('Threshold')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluate the model with the optimal threshold
y_pred_optimal = (y_pred_prob >= threshold_highest_accuracy).astype(int)

# Final evaluation metrics with the optimal threshold
print("Classification Report with Optimal Threshold:\n", classification_report(y_test, y_pred_optimal))
print("Confusion Matrix with Optimal Threshold:\n", confusion_matrix(y_test, y_pred_optimal))
# Out:
# Highest Accuracy on Test Set: 0.6815402993464971
# Threshold for Highest Accuracy: 0.56
# Classification Report with Optimal Threshold:
#                precision    recall  f1-score   support
#
#            0       0.65      0.79      0.71      7147
#            1       0.73      0.57      0.64      7084
#
#     accuracy                           0.68     14231
#    macro avg       0.69      0.68      0.68     14231
# weighted avg       0.69      0.68      0.68     14231
#
# Confusion Matrix with Optimal Threshold:
#  [[5676 1471]
#  [3061 4023]]

# %% [markdown]
# **F1 Tuning For XGBoost**

# %%
# Predict probabilities
y_pred_prob = model.predict_proba(X_test_scaled)[:, 1]

# Calculate F1 score for different thresholds
highest_f1 = 0
threshold_highest_f1 = 0

thresholds = np.arange(0, 1, 0.01)
f1_scores = []

for t in thresholds:
    y_pred_custom = (y_pred_prob >= t).astype(int)
    score = f1_score(y_test, y_pred_custom)
    f1_scores.append(score)
    if score > highest_f1:
        highest_f1 = score
        threshold_highest_f1 = t

print("Highest F1 Score on Test Set:", highest_f1)
print("Threshold for Highest F1 Score:", threshold_highest_f1)

# Plot F1 score vs. thresholds
plt.plot([0.5, 0.5], [np.min(f1_scores), np.max(f1_scores)], linestyle='--', label="Default Threshold (0.5)")
plt.plot([threshold_highest_f1, threshold_highest_f1], [np.min(f1_scores), np.max(f1_scores)], linestyle='-', label=f"Optimal Threshold ({threshold_highest_f1:.2f})")
plt.plot(thresholds, f1_scores, marker='.', label="F1 Score Curve")
plt.title('F1 Score vs. Thresholds')
plt.xlabel('Threshold')
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# Evaluate the model with the optimal threshold
y_pred_optimal = (y_pred_prob >= threshold_highest_f1).astype(int)

# Final evaluation metrics with the optimal threshold
print("Classification Report with Optimal Threshold:\n", classification_report(y_test, y_pred_optimal))
print("Confusion Matrix with Optimal Threshold:\n", confusion_matrix(y_test, y_pred_optimal))
# Out:
# Highest F1 Score on Test Set: 0.701195219123506
# Threshold for Highest F1 Score: 0.34
# Classification Report with Optimal Threshold:
#                precision    recall  f1-score   support
#
#            0       0.74      0.44      0.55      7147
#            1       0.60      0.84      0.70      7084
#
#     accuracy                           0.64     14231
#    macro avg       0.67      0.64      0.63     14231
# weighted avg       0.67      0.64      0.63     14231
#
# Confusion Matrix with Optimal Threshold:
#  [[3147 4000]
#  [1100 5984]]

# %% [markdown]
# # **Feature Importnace XGboost**

# %%
# Preprocessing
df['DEP_TIME_START'] = df['DEP_TIME_BLK'].str.split('-').str[0].astype(int)

label_encoder = LabelEncoder()
df['CARRIER_NAME'] = label_encoder.fit_transform(df['CARRIER_NAME'])
df['DEPARTING_AIRPORT'] = label_encoder.fit_transform(df['DEPARTING_AIRPORT'])
df = df.dropna()

# Select features and target variable
X = df[['MONTH', 'DAY_OF_WEEK', 'DEP_TIME_START', 'DISTANCE_GROUP',
        'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS',
        'AIRPORT_FLIGHTS_MONTH', 'PLANE_AGE', 'LATITUDE', 'LONGITUDE',
        'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND']]
y = df['DEP_DEL15']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardise the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train XGBoost model
model = XGBClassifier(n_estimators=100, random_state=42, use_label_encoder=False, eval_metric='logloss')
model.fit(X_train_scaled, y_train)

# Predictions and Evaluation
y_pred = model.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))

# Extract feature importance
feature_importance = model.feature_importances_

# Map feature importance to feature names
importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)

print("Feature Importance:\n", importance_df)

# Plot feature importance
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.title('Feature Importance')
plt.gca().invert_yaxis()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:53:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Accuracy: 0.6799241093387675
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69      7147
#            1       0.69      0.65      0.67      7084
#
#     accuracy                           0.68     14231
#    macro avg       0.68      0.68      0.68     14231
# weighted avg       0.68      0.68      0.68     14231
#
# Confusion Matrix:
#  [[5097 2050]
#  [2505 4579]]
# Feature Importance:
#                    Feature  Importance
# 2          DEP_TIME_START    0.152316
# 11                   PRCP    0.110377
# 12                   SNOW    0.108751
# 13                   SNWD    0.079760
# 14                   TMAX    0.076162
# 0                   MONTH    0.069700
# 7   AIRPORT_FLIGHTS_MONTH    0.061624
# 4          SEGMENT_NUMBER    0.058007
# 6         NUMBER_OF_SEATS    0.053256
# 15                   AWND    0.052921
# 1             DAY_OF_WEEK    0.049633
# 3          DISTANCE_GROUP    0.049082
# 5      CONCURRENT_FLIGHTS    0.039424
# 8               PLANE_AGE    0.038986
# 9                LATITUDE    0.000000
# 10              LONGITUDE    0.000000

# %%
# Plot feature importance
plt.figure(figsize=(10, 8))
plot_importance(model, importance_type='weight', title='Feature Importance (XGBoost)')
plt.show()

# %%
# Get probabilities for the positive class
y_pred_proba = model.predict_proba(X_test_scaled)[:, 1]

# Calculate ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
auc_score = roc_auc_score(y_test, y_pred_proba)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.2f})", color="blue")
plt.plot([0, 1], [0, 1], 'k--', label="Random Guessing")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.grid()
plt.show()

# Print the AUC score
print(f"Area Under the Curve (AUC): {auc_score:.2f}")
# Out:
# Area Under the Curve (AUC): 0.75

# %% [markdown]
# # **Hyperparameter Optimisation for** **XGBoost**

# %%
# Prepare DMatrix for XGBoost
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# Define parameter grid for hyperparameter tuning
param_grid = {
    'max_depth': [3, 5, 7],
    'eta': [0.01, 0.1, 0.3],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'objective': ['binary:logistic']
}

# Initialise the XGBoost classifier
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')

# Set up GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=3,
    verbose=1
)

# Perform grid search
grid_search.fit(X_train, y_train)

# Extract the best model from grid search
best_xgb_model = grid_search.best_estimator_

# Make predictions on the test set
y_pred_xgb = best_xgb_model.predict(X_test)

# Evaluate the model
xgb_accuracy = accuracy_score(y_test, y_pred_xgb)
xgb_classification_report = classification_report(y_test, y_pred_xgb)
xgb_confusion_matrix = confusion_matrix(y_test, y_pred_xgb)

# Display results
xgb_accuracy, xgb_classification_report, xgb_confusion_matrix
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:56:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:57:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:58:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:25] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:43] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [11:59:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:20] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:23] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:47] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:57] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:00:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:03] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:05] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:14] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:30] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:35] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:42] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:45] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:50] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:53] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:56] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:01:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:01] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:07] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:11] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:17] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:19] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:21] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:22] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:24] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:26] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:28] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:36] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:37] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:38] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:40] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:41] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:44] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:46] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:48] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:49] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:51] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:52] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:54] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:02:58] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:03:00] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:03:02] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:03:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:03:06] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:03:08] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:03:10] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:03:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:03:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:03:16] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:03:18] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# (0.6605366639857839,
#  '              precision    recall  f1-score   support\n\n           0       0.66      0.68      0.67    157229\n           1       0.67      0.64      0.66    157344\n\n    accuracy                           0.66    314573\n   macro avg       0.66      0.66      0.66    314573\nweighted avg       0.66      0.66      0.66    314573\n',
#  array([[106417,  50812],
#         [ 55974, 101370]]))

# %% [markdown]
# **Best parameters**

# %%
grid_search.best_params_
# Out:
# {'colsample_bytree': 1.0,
#  'eta': 0.3,
#  'max_depth': 7,
#  'objective': 'binary:logistic',
#  'subsample': 1.0}

# %%
#Best grid search parameters
# {'colsample_bytree': 1.0,
#  'eta': 0.3,
#  'max_depth': 7,
#  'objective': 'binary:logistic',
#  'subsample': 1.0}

# %%
best_xgb_model = grid_search.best_estimator_
best_xgb_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:09:15] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.3, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=7,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb = best_xgb_model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred_xgb))
print("Classification Report:\n", classification_report(y_test, y_pred_xgb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb))
# Out:
# Accuracy: 0.6605366639857839
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67    157229
#            1       0.67      0.64      0.66    157344
#
#     accuracy                           0.66    314573
#    macro avg       0.66      0.66      0.66    314573
# weighted avg       0.66      0.66      0.66    314573
#
# Confusion Matrix:
#  [[106417  50812]
#  [ 55974 101370]]

# %%
xgb.plot_importance(best_xgb_model, max_num_features=10)
plt.show()

# %%
y_pred_prob = best_xgb_model.predict_proba(X_test)[:, 1]

# %%
scores = cross_val_score(best_xgb_model, X_train, y_train, cv=5, scoring='accuracy')
print("Cross-validation accuracy scores:", scores)
print("Mean cross-validation accuracy:", scores.mean())
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:09:27] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:09:29] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:09:31] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:09:33] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [12:09:34] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Cross-validation accuracy scores: [0.66017261 0.66041103 0.65894414 0.66050409 0.65985014]
# Mean cross-validation accuracy: 0.6599764024745951

# %% [markdown]
# **ROC curve for XGBoost**

# %%
# Get probabilities for the positive class
y_pred_proba = model.predict_proba(X_test_scaled)[:, 1]

# Calculate ROC curve and AUC score
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
auc_score = roc_auc_score(y_test, y_pred_proba)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc_score:.2f})", color="blue")
plt.plot([0, 1], [0, 1], 'k--', label="Random Guessing")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.grid()
plt.show()

# Print the AUC score
print(f"Area Under the Curve (AUC): {auc_score:.2f}")
# Out:
# Area Under the Curve (AUC): 0.72

# %% [markdown]
# # **Lasso predictive model**

# %%
# Extract numeric time from 'DEP_TIME_BLK'
df['DEP_TIME_START'] = df['DEP_TIME_BLK'].str.split('-').str[0].astype(int)

# Convert categorical variables into numerical values
label_encoder = LabelEncoder()

# Example: Encoding 'CARRIER_NAME' and 'DEPARTING_AIRPORT'
df['CARRIER_NAME'] = label_encoder.fit_transform(df['CARRIER_NAME'])
df['DEPARTING_AIRPORT'] = label_encoder.fit_transform(df['DEPARTING_AIRPORT'])

# Handle missing values
df = df.dropna()

# Select features and target variable
X = df[['MONTH', 'DAY_OF_WEEK', 'DEP_TIME_START', 'DISTANCE_GROUP',
        'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS',
        'AIRPORT_FLIGHTS_MONTH', 'PLANE_AGE', 'LATITUDE', 'LONGITUDE',
        'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND']]

# Target variable
y = df['DEP_DEL15']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 4: Standardise the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the Lasso model
model = Lasso(alpha=1.0, random_state=42)
model.fit(X_train_scaled, y_train)

# Predictions and Evaluation
y_pred = model.predict(X_test_scaled)

# Evaluate model
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error (MSE): 0.2500005427914466
# Mean Absolute Error (MAE): 0.5000002106781619
# R² Score: -2.3048111186252385e-06

# %% [markdown]
# # **SVM**

# %%
# Extract numeric time from 'DEP_TIME_BLK'
df['DEP_TIME_START'] = df['DEP_TIME_BLK'].str.split('-').str[0].astype(int)

# Encode categorical features
label_encoder = LabelEncoder()
df['CARRIER_NAME'] = label_encoder.fit_transform(df['CARRIER_NAME'])
df['DEPARTING_AIRPORT'] = label_encoder.fit_transform(df['DEPARTING_AIRPORT'])

# Select features and target
X = df[['MONTH', 'DAY_OF_WEEK', 'DEP_TIME_START', 'DISTANCE_GROUP',
        'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS',
        'AIRPORT_FLIGHTS_MONTH', 'PLANE_AGE', 'LATITUDE', 'LONGITUDE',
        'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND']]
y = df['DEP_DEL15']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardise the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the SVM model
svm_model = SVC(kernel='linear', probability=True, random_state=42)
svm_model.fit(X_train_scaled, y_train)

# Predictions and Evaluation
y_pred_svm = svm_model.predict(X_test_scaled)

# Evaluate SVM model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
classification_report_svm = classification_report(y_test, y_pred_svm)
confusion_matrix_svm = confusion_matrix(y_test, y_pred_svm)

# Print results
print("SVM Model Accuracy:", accuracy_svm)
print("SVM Model Classification Report:\n", classification_report_svm)
print("SVM Model Confusion Matrix:\n", confusion_matrix_svm)
# Out:
# SVM Model Accuracy: 0.6277141451760242
# SVM Model Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.59      0.61      7147
#            1       0.62      0.67      0.64      7084
#
#     accuracy                           0.63     14231
#    macro avg       0.63      0.63      0.63     14231
# weighted avg       0.63      0.63      0.63     14231
#
# SVM Model Confusion Matrix:
#  [[4197 2950]
#  [2348 4736]]

# %% [markdown]
# # **Stacking Ensembele Model**

# %%
# Preprocessing Steps
label_encoder = LabelEncoder()
df['CARRIER_NAME'] = label_encoder.fit_transform(df['CARRIER_NAME'])
df['DEPARTING_AIRPORT'] = label_encoder.fit_transform(df['DEPARTING_AIRPORT'])
df['DEP_TIME_START'] = df['DEP_TIME_BLK'].str.split('-').str[0].astype(int)

# Drop rows with missing values
df = df.dropna()

# Feature Selection
X = df[['MONTH', 'DAY_OF_WEEK', 'DEP_TIME_START', 'DISTANCE_GROUP',
        'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS',
        'AIRPORT_FLIGHTS_MONTH', 'PLANE_AGE', 'LATITUDE', 'LONGITUDE',
        'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND']]
y = df['DEP_DEL15']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scaling the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Base Models
log_clf = LogisticRegression(max_iter=1000)
rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)
gb_clf = GradientBoostingClassifier(n_estimators=100, random_state=42)
dt_clf = DecisionTreeClassifier(random_state=42)
hgb_clf = HistGradientBoostingClassifier(random_state=42)
svm_clf = SVC(probability=True, random_state=42)

# Meta-Model
final_estimator = LogisticRegression()

# Stacking Ensemble
estimators = [
    ('lr', log_clf),
    ('rf', rf_clf),
    ('gb', gb_clf),
    ('dt', dt_clf),
    ('hgb', hgb_clf),
    ('svm', svm_clf)
]

stack_clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator, cv=5)

# Train and Predict
stack_clf.fit(X_train_scaled, y_train)
y_pred = stack_clf.predict(X_test_scaled)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6896915185159159
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.73      0.70      7147
#            1       0.70      0.65      0.68      7084
#
#     accuracy                           0.69     14231
#    macro avg       0.69      0.69      0.69     14231
# weighted avg       0.69      0.69      0.69     14231

# %% [markdown]
# # **Deep Neural Network**

# %%
# Preprocessing Steps
label_encoder = LabelEncoder()
df['CARRIER_NAME'] = label_encoder.fit_transform(df['CARRIER_NAME'])
df['DEPARTING_AIRPORT'] = label_encoder.fit_transform(df['DEPARTING_AIRPORT'])
df['DEP_TIME_START'] = df['DEP_TIME_BLK'].str.split('-').str[0].astype(int)
df = df.dropna()

# Feature Selection
X = df[['MONTH', 'DAY_OF_WEEK', 'DEP_TIME_START', 'DISTANCE_GROUP',
        'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS',
        'AIRPORT_FLIGHTS_MONTH', 'PLANE_AGE', 'LATITUDE', 'LONGITUDE',
        'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND']]
y = df['DEP_DEL15']

# One-hot encode target variable for neural network
y_nn = to_categorical(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y_nn, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Deep Neural Network
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train_scaled, y_train, epochs=20, batch_size=32, validation_data=(X_test_scaled, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print("Neural Network Accuracy:", accuracy)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6081 - loss: 0.6613 - val_accuracy: 0.6437 - val_loss: 0.6371
# Epoch 2/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6306 - loss: 0.6425 - val_accuracy: 0.6456 - val_loss: 0.6312
# Epoch 3/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6404 - loss: 0.6357 - val_accuracy: 0.6475 - val_loss: 0.6288
# Epoch 4/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6448 - loss: 0.6305 - val_accuracy: 0.6524 - val_loss: 0.6238
# Epoch 5/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6455 - loss: 0.6298 - val_accuracy: 0.6515 - val_loss: 0.6279
# Epoch 6/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6499 - loss: 0.6282 - val_accuracy: 0.6534 - val_loss: 0.6243
# Epoch 7/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6488 - loss: 0.6276 - val_accuracy: 0.6512 - val_loss: 0.6224
# Epoch 8/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6504 - loss: 0.6231 - val_accuracy: 0.6520 - val_loss: 0.6248
# Epoch 9/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6536 - loss: 0.6228 - val_accuracy: 0.6535 - val_loss: 0.6198
# Epoch 10/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6525 - loss: 0.6236 - val_accuracy: 0.6526 - val_loss: 0.6208
# Epoch 11/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6507 - loss: 0.6229 - val_accuracy: 0.6536 - val_loss: 0.6195
# Epoch 12/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6531 - loss: 0.6203 - val_accuracy: 0.6539 - val_loss: 0.6213
# Epoch 13/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6560 - loss: 0.6215 - val_accuracy: 0.6571 - val_loss: 0.6200
# Epoch 14/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6529 - loss: 0.6200 - val_accuracy: 0.6547 - val_loss: 0.6200
# Epoch 15/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6554 - loss: 0.6197 - val_accuracy: 0.6562 - val_loss: 0.6191
# Epoch 16/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6579 - loss: 0.6175 - val_accuracy: 0.6558 - val_loss: 0.6230
# Epoch 17/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6558 - loss: 0.6172 - val_accuracy: 0.6572 - val_loss: 0.6174
# Epoch 18/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6592 - loss: 0.6157 - val_accuracy: 0.6560 - val_loss: 0.6182
# Epoch 19/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6623 - loss: 0.6146 - val_accuracy: 0.6565 - val_loss: 0.6191
# Epoch 20/20
# 1038/1038 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6544 - loss: 0.6160 - val_accuracy: 0.6598 - val_loss: 0.6156
# 445/445 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.6641 - loss: 0.6137
# Neural Network Accuracy: 0.6597568392753601
